# %%
import os
import pandas as pd
import numpy as np

# %%
CLASS_NAMES = ['Atelectasis', 'Cardiomegaly', 'Effusion', 'Infiltration', 'Mass', 'Nodule', 'Pneumonia',
               'Pneumothorax', 'Consolidation', 'Edema', 'Emphysema', 'Fibrosis', 'Pleural_Thickening', 'Hernia']
image_names = np.load('./result/{}.npz'.format('CheXNet_image_names'))['arr_0']
pred = np.load('./result/{}.npz'.format('CheXNet_pred'))['arr_0']

# %%
data = pd.DataFrame()
data['filenames'] = image_names
for i, each in enumerate(CLASS_NAMES):
    data[each] = pred[:, i]
print(data)
# Out:
#      filenames  Atelectasis  Cardiomegaly  Effusion  Infiltration      Mass  \
# 0      624.png     0.023403      0.022237  0.009396      0.206533  0.029474
# 1      802.png     0.017082      0.001849  0.003149      0.066216  0.006244
# 2      280.png     0.004106      0.001201  0.000538      0.050010  0.000766
# 3      615.png     0.015374      0.015774  0.004696      0.104450  0.010667
# 4      140.png     0.007844      0.001371  0.003183      0.090185  0.011991
# 5      660.png     0.015076      0.000683  0.004716      0.041210  0.048004
# 6      518.png     0.026400      0.003497  0.005651      0.217709  0.010260
# 7      337.png     0.006272      0.000529  0.004063      0.029247  0.005080
# 8      516.png     0.034861      0.000511  0.006760      0.087422  0.008695
# 9      284.png     0.001190      0.001260  0.001233      0.052995  0.006981
# 10     662.png     0.018910      0.001028  0.002763      0.109080  0.002101
# ...
